# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Model,Sequential
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.optimizers import Adam
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.utils import pad_sequences
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/spam.csv',encoding='latin-1')
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v1      5572 non-null   object
#  1   v2      5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
sns.countplot(df.v1)
plt.xlabel('Label')
plt.title('Number of ham and spam messages')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Number of ham and spam messages')

# %%
X = df.v2
Y = df.v1
le = LabelEncoder()
Y = le.fit_transform(Y)
Y = Y.reshape(-1,1)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.15)

# %%
max_words = 1000
max_len = 150
tok = Tokenizer(num_words=max_words)
tok.fit_on_texts(X_train)
sequences = tok.texts_to_sequences(X_train)
sequences_matrix = pad_sequences(sequences,maxlen=max_len)
sequences_matrix
# Out:
# array([[  0,   0,   0, ..., 518,  18, 164],
#        [  0,   0,   0, ...,  28,   3,  57],
#        [  0,   0,   0, ..., 414,   8, 341],
#        ...,
#        [  0,   0,   0, ...,  82,  18, 989],
#        [  0,   0,   0, ..., 640, 569, 218],
#        [  0,   0,   0, ...,   2,   3, 104]], dtype=int32)

# %%
tok.index_word
# Out:
# {1: 'i',
#  2: 'to',
#  3: 'you',
#  4: 'a',
#  5: 'the',
#  6: 'u',
#  7: 'and',
#  8: 'in',
#  9: 'is',
#  10: 'me',
#  11: 'my',
#  12: 'for',
#  13: 'your',
#  14: 'it',
#  15: 'of',
#  16: 'call',
#  17: 'have',
#  18: '2',
#  19: 'on',
#  20: 'that',
#  21: 'now',
#  22: 'are',
#  23: 'so',
#  24: 'but',
#  25: 'not',
#  26: 'or',
#  27: 'can',
#  28: 'do',
#  29: 'at',
#  30: 'with',
#  31: 'be',
#  32: "i'm",
#  33: 'will',
#  34: 'get',
#  35: 'ur',
#  36: 'if',
#  37: 'just',
#  38: 'no',
#  39: 'we',
#  40: 'this',
#  41: '4',
#  42: 'up',
#  43: 'when',
#  44: 'gt',
#  45: 'lt',
#  46: 'ok',
#  47: 'how',
#  48: 'go',
#  49: 'free',
#  50: 'from',
#  51: 'out',
#  52: 'all',
#  53: 'what',
#  54: 'know',
#  55: 'then',
#  56: 'good',
#  57: 'like',
#  58: 'got',
#  59: 'was',
#  60: 'its',
#  61: 'come',
#  62: 'time',
#  63: 'am',
#  64: 'day',
#  65: 'love',
#  66: 'only',
#  67: 'send',
#  68: 'want',
#  69: 'there',
#  70: 'text',
#  71: 'as',
#  72: 'txt',
#  73: 'he',
#  74: 'going',
#  75: 'one',
#  76: "i'll",
#  77: 'home',
#  78: 'still',
#  79: 'by',
#  80: 'lor',
#  81: 'about',
#  82: 'need',
#  83: 'r',
#  84: 'stop',
#  85: 'back',
#  86: 'k',
#  87: 'sorry',
#  88: 'our',
#  89: 'da',
#  90: 'today',
#  91: 'she',
#  92: 'n',
#  93: "don't",
#  94: 'see',
#  95: 'dont',
#  96: 'reply',
#  97: 'mobile',
#  98: 'hi',
#  99: 'pls',
#  100: 'tell',
#  101: 'new',
#  102: 'her',
#  103: 'take',
#  104: 'later',
#  105: 'think',
#  106: 'any',
#  107: 'they',
#  108: 'phone',
#  109: 'ì',
#  110: 'please',
#  111: 'week',
#  112: 'dear',
#  113: 'been',
#  114: '1',
#  115: 'here',
#  116: 'much',
#  117: 'claim',
#  118: 'msg',
#  119: 'did',
#  120: 'great',
#  121: 'oh',
#  122: 'some',
#  123: 'well',
#  124: 'an',
#  125: 'hey',
#  126: 'd',
#  127: 'who',
#  128: 'night',
#  129: 'more',
#  130: 'too',
#  131: 'where',
#  132: 'c',
#  133: 'hope',
#  134: 'happy',
#  135: 'him',
#  136: 'had',
#  137: 'has',
#  138: 'make',
#  139: 'give',
#  140: 'wat',
#  141: 'way',
#  142: 'work',
#  143: 'yes',
#  144: 'number',
#  145: 'after',
#  146: 'should',
#  147: 'www',
#  148: 'prize',
#  149: 'message',
#  150: 'right',
#  151: 'say',
#  152: "it's",
#  153: 'really',
#  154: 'already',
#  155: 'e',
#  156: 'ask',
#  157: 'yeah',
#  158: 'cash',
#  159: 'very',
#  160: 'doing',
#  161: 'them',
#  162: 'tomorrow',
#  163: '3',
#  164: 'meet',
#  165: 'babe',
#  166: 'said',
#  167: 'life',
#  168: 'amp',
#  169: 'thanks',
#  170: 'im',
#  171: 'last',
#  172: 'cos',
#  173: 't',
#  174: 'why',
#  175: 'morning',
#  176: 'anything',
#  177: 'urgent',
#  178: 'miss',
#  179: 'find',
#  180: 'keep',
#  181: 'won',
#  182: 'also',
#  183: 'sure',
#  184: 'sent',
#  185: 'b',
#  186: 'let',
#  187: 'every',
#  188: 'pick',
#  189: 'min',
#  190: 'nokia',
#  191: 'win',
#  192: '150p',
#  193: 'lol',
#  194: 'would',
#  195: 'com',
#  196: 'contact',
#  197: 'over',
#  198: 'uk',
#  199: 'care',
#  200: 'again',
#  201: 'buy',
#  202: 'us',
#  203: 'cant',
#  204: 'went',
#  205: 'first',
#  206: 'feel',
#  207: 'were',
#  208: 'around',
#  209: 'before',
#  210: 'could',
#  211: "can't",
#  212: "i've",
#  213: 'something',
#  214: 'per',
#  215: 'someone',
#  216: 'off',
#  217: 'thing',
#  218: 'soon',
#  219: 'other',
#  220: 'even',
#  221: 's',
#  222: '5',
#  223: 'which',
#  224: 'customer',
#  225: 'service',
#  226: 'late',
#  227: "that's",
#  228: 'next',
#  229: 'leave',
#  230: 'x',
#  231: 'ya',
#  232: 'many',
#  233: '50',
#  234: 'tone',
#  235: 'sleep',
#  236: 'waiting',
#  237: 'tonight',
#  238: 'his',
#  239: 'gonna',
#  240: 'money',
#  241: 'chat',
#  242: 'v',
#  243: 'gud',
#  244: 'dun',
#  245: 'wait',
#  246: 'same',
#  247: 'nice',
#  248: '16',
#  249: 'always',
#  250: 'place',
#  251: 'co',
#  252: 'wish',
#  253: 'wan',
#  254: 'may',
#  255: 'yet',
#  256: 'friends',
#  257: 'use',
#  258: 'ìï',
#  259: 'told',
#  260: '18',
#  261: "you're",
#  262: 'hello',
#  263: 'special',
#  264: 'down',
#  265: 'sms',
#  266: 'getting',
#  267: 'smile',
#  268: 'haha',
#  269: 'holiday',
#  270: 'guaranteed',
#  271: 'done',
#  272: 'things',
#  273: 'help',
#  274: 'mins',
#  275: 'live',
#  276: 'friend',
#  277: 'thk',
#  278: 'heart',
#  279: 'days',
#  280: 'year',
#  281: 'name',
#  282: 'coming',
#  283: 'people',
#  284: 'draw',
#  285: 'fine',
#  286: 'thought',
#  287: 'having',
#  288: 'talk',
#  289: 'class',
#  290: "didn't",
#  291: 'try',
#  292: 'stuff',
#  293: 'yup',
#  294: 'best',
#  295: 'thats',
#  296: 'bit',
#  297: 'person',
#  298: 'few',
#  299: 'cool',
#  300: 'man',
#  301: 'better',
#  302: '6',
#  303: 'finish',
#  304: 'cs',
#  305: 'line',
#  306: 'y',
#  307: 'long',
#  308: 'ready',
#  309: 'house',
#  310: 'trying',
#  311: 'lunch',
#  312: 'dat',
#  313: 'girl',
#  314: 'check',
#  315: 'lot',
#  316: 'mind',
#  317: 'awarded',
#  318: 'camera',
#  319: 'job',
#  320: 'meeting',
#  321: 'because',
#  322: 'yo',
#  323: 'play',
#  324: 'wk',
#  325: 'sir',
#  326: 'than',
#  327: 'nothing',
#  328: 'word',
#  329: 'start',
#  330: 'problem',
#  331: 'never',
#  332: 'ill',
#  333: '7',
#  334: 'eat',
#  335: 'guess',
#  336: 'lar',
#  337: 'into',
#  338: 'wanna',
#  339: 'receive',
#  340: 'real',
#  341: 'bed',
#  342: 'latest',
#  343: 'big',
#  344: 'account',
#  345: 'end',
#  346: 'offer',
#  347: 'being',
#  348: 'might',
#  349: 'world',
#  350: 'birthday',
#  351: 'month',
#  352: 'another',
#  353: 'car',
#  354: 'shows',
#  355: 'shit',
#  356: 'box',
#  357: 'å£1',
#  358: 'landline',
#  359: 'enjoy',
#  360: 'guys',
#  361: 'quite',
#  362: '1st',
#  363: 'half',
#  364: 'watching',
#  365: 'bt',
#  366: 'tv',
#  367: 'å£1000',
#  368: 'god',
#  369: 'po',
#  370: 'sweet',
#  371: 'cost',
#  372: 'princess',
#  373: 'speak',
#  374: 'xxx',
#  375: 'dinner',
#  376: 'once',
#  377: '150ppm',
#  378: 'jus',
#  379: 'watch',
#  380: 'ringtone',
#  381: 'chance',
#  382: 'early',
#  383: 'does',
#  384: 'pay',
#  385: 'ever',
#  386: 'rate',
#  387: 'luv',
#  388: 'probably',
#  389: 'shall',
#  390: 'reach',
#  391: 'dis',
#  392: 'liao',
#  393: 'room',
#  394: 'maybe',
#  395: 'video',
#  396: 'actually',
#  397: 'boy',
#  398: 'den',
#  399: 'those',
#  400: "how's",
#  401: 'sat',
#  402: 'minutes',
#  403: 'kiss',
#  404: 'easy',
#  405: 'left',
#  406: 'weekend',
#  407: 'hear',
#  408: 'between',
#  409: 'two',
#  410: 'looking',
#  411: 'remember',
#  412: 'plan',
#  413: 'pa',
#  414: 'hour',
#  415: 'part',
#  416: 'wife',
#  417: 'ah',
#  418: 'code',
#  419: 'dunno',
#  420: '2nd',
#  421: 'fun',
#  422: '000',
#  423: 'wont',
#  424: 'bus',
#  425: 'called',
#  426: 'll',
#  427: 'baby',
#  428: 'leh',
#  429: 'aight',
#  430: 'made',
#  431: 'fuck',
#  432: 'm',
#  433: '10',
#  434: 'thanx',
#  435: 'bad',
#  436: '9',
#  437: 'sexy',
#  438: "he's",
#  439: 'forgot',
#  440: 'office',
#  441: 'texts',
#  442: 'look',
#  443: 'evening',
#  444: 'years',
#  445: 'afternoon',
#  446: 'since',
#  447: 'calls',
#  448: 'shopping',
#  449: 'join',
#  450: 'asked',
#  451: 'details',
#  452: 'dad',
#  453: 'award',
#  454: 'while',
#  455: 'didnt',
#  456: 'mail',
#  457: 'de',
#  458: 'put',
#  459: '8',
#  460: 'network',
#  461: 'town',
#  462: 'selected',
#  463: 'orange',
#  464: 'though',
#  465: 'anyway',
#  466: 'plz',
#  467: 'xmas',
#  468: 'entry',
#  469: 'little',
#  470: "there's",
#  471: 'apply',
#  472: 'enough',
#  473: 'wake',
#  474: 'bring',
#  475: 'tmr',
#  476: 'goes',
#  477: 'price',
#  478: 'important',
#  479: 'dude',
#  480: 'hot',
#  481: 'attempt',
#  482: 'collection',
#  483: 'feeling',
#  484: 'collect',
#  485: 'juz',
#  486: 'wanted',
#  487: 'without',
#  488: 'makes',
#  489: 'else',
#  490: 'plus',
#  491: 'missed',
#  492: 'run',
#  493: 're',
#  494: 'everything',
#  495: 'bored',
#  496: 'saw',
#  497: 'delivery',
#  498: 'g',
#  499: 'top',
#  500: 'means',
#  501: 'question',
#  502: 'guy',
#  503: 'å£100',
#  504: 'most',
#  505: 'net',
#  506: '10p',
#  507: '500',
#  508: 'tones',
#  509: 'says',
#  510: 'working',
#  511: 'okay',
#  512: 'came',
#  513: 'valid',
#  514: 'thank',
#  515: 'worry',
#  516: 'abt',
#  517: 'oso',
#  518: 'haf',
#  519: 'alright',
#  520: 'havent',
#  521: 'pain',
#  522: 'colour',
#  523: 'music',
#  524: 'hours',
#  525: 'online',
#  526: 'messages',
#  527: 'able',
#  528: 'weekly',
#  529: 'away',
#  530: 'show',
#  531: 'national',
#  532: 'hav',
#  533: 'goin',
#  534: "what's",
#  535: 'must',
#  536: 'sch',
#  537: 'friendship',
#  538: 'either',
#  539: 'times',
#  540: 'wants',
#  541: 'tried',
#  542: 'until',
#  543: 'wot',
#  544: 'ard',
#  545: 'wif',
#  546: 'hair',
#  547: 'mob',
#  548: 'true',
#  549: 'update',
#  550: 'gift',
#  551: 'til',
#  552: 'thinking',
#  553: 'answer',
#  554: 'noe',
#  555: "we're",
#  556: 'full',
#  557: 'double',
#  558: 'stay',
#  559: 'family',
#  560: 'decimal',
#  561: 'movie',
#  562: 'vouchers',
#  563: 'lei',
#  564: 'yourself',
#  565: 'yours',
#  566: 'bonus',
#  567: 'old',
#  568: "we'll",
#  569: 'id',
#  570: 'nite',
#  571: 'shop',
#  572: 'making',
#  573: 'till',
#  574: 'test',
#  575: '750',
#  576: 'yesterday',
#  577: 'together',
#  578: 'driving',
#  579: "haven't",
#  580: 'smiling',
#  581: 'tomo',
#  582: 'words',
#  583: 'todays',
#  584: 'sae',
#  585: 'pics',
#  586: 'both',
#  587: 'beautiful',
#  588: 'change',
#  589: 'rite',
#  590: 'saying',
#  591: 'busy',
#  592: 'comes',
#  593: 'trip',
#  594: 'eve',
#  595: 'book',
#  596: 'post',
#  597: 'believe',
#  598: 'charge',
#  599: 'calling',
#  600: 'story',
#  601: '8007',
#  602: 'everyone',
#  603: 'order',
#  604: 'head',
#  605: 'game',
#  606: 'å£5000',
#  607: 'å£500',
#  608: 'minute',
#  609: 'set',
#  610: 'missing',
#  611: 'tot',
#  612: 'these',
#  613: '86688',
#  614: 'await',
#  615: 'http',
#  616: 'wen',
#  617: 'xx',
#  618: 'pic',
#  619: 'leaving',
#  620: 'club',
#  621: 'tho',
#  622: 'hurt',
#  623: 'cause',
#  624: 'walk',
#  625: 'drop',
#  626: 'happen',
#  627: 'pounds',
#  628: 'food',
#  629: "''",
#  630: 'knw',
#  631: 'services',
#  632: 'hard',
#  633: 'info',
#  634: 'opt',
#  635: 'points',
#  636: 'card',
#  637: 'ring',
#  638: 'coz',
#  639: 'started',
#  640: 'email',
#  641: 'awesome',
#  642: 'huh',
#  643: 'brother',
#  644: 'drink',
#  645: 'anyone',
#  646: 'sad',
#  647: 'aft',
#  648: 'date',
#  649: 'took',
#  650: 'land',
#  651: 'taking',
#  652: 'second',
#  653: 'loving',
#  654: 'å£2000',
#  655: 'final',
#  656: 'drive',
#  657: 'touch',
#  658: 'school',
#  659: 'needs',
#  660: 'lose',
#  661: 'whatever',
#  662: 'auction',
#  663: 'pm',
#  664: 'sleeping',
#  665: 'congrats',
#  666: 'wid',
#  667: 'games',
#  668: 'chikku',
#  669: '\x89û',
#  670: 'mum',
#  671: 'takes',
#  672: '08000930705',
#  673: 'decided',
#  674: "won't",
#  675: 'choose',
#  676: "c's",
#  677: 'close',
#  678: 'ltd',
#  679: 'don',
#  680: 'worth',
#  681: 'address',
#  682: 'mine',
#  683: 'read',
#  684: 'row',
#  685: 'simple',
#  686: 'dating',
#  687: 'found',
#  688: 'w',
#  689: 'fucking',
#  690: 'neva',
#  691: 'far',
#  692: 'news',
#  693: 'ha',
#  694: '12hrs',
#  695: 'smth',
#  696: 'oredi',
#  697: 'mean',
#  698: 'alone',
#  699: 'girls',
#  700: 'face',
#  701: 'treat',
#  702: 'unsubscribe',
#  703: 'whats',
#  704: 'voucher',
#  705: 'boytoy',
#  706: 'sea',
#  707: 'mu',
#  708: 'type',
#  709: 'anytime',
#  710: 'camcorder',
#  711: 'friday',
#  712: 'kind',
#  713: 'smoke',
#  714: 'pub',
#  715: 'wil',
#  716: 'private',
#  717: 'statement',
#  718: 'expires',
#  719: 'congratulations',
#  720: 'winner',
#  721: 'okie',
#  722: 'hit',
#  723: 'hand',
#  724: '100',
#  725: 'wkly',
#  726: 'å£3',
#  727: 'quiz',
#  728: 'fri',
#  729: 'carlos',
#  730: 'finished',
#  731: 'hold',
#  732: 'fast',
#  733: 'goodmorning',
#  734: 'break',
#  735: 'available',
#  736: 'hmm',
#  737: 'ten',
#  738: 'sis',
#  739: 'poly',
#  740: 'light',
#  741: 'gr8',
#  742: 'saturday',
#  743: 'unlimited',
#  744: 'secret',
#  745: 'sunday',
#  746: 'lucky',
#  747: 'angry',
#  748: 'wrong',
#  749: 'luck',
#  750: 'least',
#  751: 'player',
#  752: 'content',
#  753: 'search',
#  754: 'sounds',
#  755: 'blue',
#  756: '11',
#  757: 'identifier',
#  758: 'yr',
#  759: 'gone',
#  760: 'seeing',
#  761: 'å£250',
#  762: 'party',
#  763: 'mate',
#  764: 'freemsg',
#  765: '30',
#  766: 'pobox',
#  767: 'gd',
#  768: 'dreams',
#  769: 'lovely',
#  770: 'earlier',
#  771: 'outside',
#  772: 'lets',
#  773: 'tel',
#  774: 'darlin',
#  775: 'mobileupd8',
#  776: 'lesson',
#  777: 'parents',
#  778: 'forget',
#  779: 'used',
#  780: 'project',
#  781: 'prob',
#  782: 'fancy',
#  783: 'chennai',
#  784: 'telling',
#  785: 'sister',
#  786: 'christmas',
#  787: 'msgs',
#  788: 'sun',
#  789: 'log',
#  790: 'thinks',
#  791: 'nt',
#  792: 'frnds',
#  793: 'crazy',
#  794: "she's",
#  795: 'grins',
#  796: 'mates',
#  797: 'open',
#  798: 'snow',
#  799: 'pass',
#  800: 'å£2',
#  801: 'correct',
#  802: '03',
#  803: 'march',
#  804: 'bout',
#  805: 'gas',
#  806: 'mah',
#  807: 'balance',
#  808: 'currently',
#  809: 'reading',
#  810: 'cum',
#  811: 'hows',
#  812: 'frnd',
#  813: "i'd",
#  814: 'college',
#  815: '08000839402',
#  816: 'na',
#  817: 'credit',
#  818: 'operator',
#  819: 'company',
#  820: 'listen',
#  821: 'valued',
#  822: 'fone',
#  823: 'within',
#  824: 'reason',
#  825: 'course',
#  826: "doesn't",
#  827: 'wit',
#  828: 'felt',
#  829: 'tired',
#  830: 'caller',
#  831: 'mayb',
#  832: 'lots',
#  833: 'visit',
#  834: 'rs',
#  835: 'pretty',
#  836: 'nope',
#  837: 'gal',
#  838: 'yar',
#  839: 'suite342',
#  840: '2lands',
#  841: 'area',
#  842: 'download',
#  843: 'happiness',
#  844: 'ni8',
#  845: 'f',
#  846: 'enter',
#  847: 'press',
#  848: 'each',
#  849: 'weeks',
#  850: 'mr',
#  851: 'hee',
#  852: 'point',
#  853: 'askd',
#  854: 'etc',
#  855: '2003',
#  856: '800',
#  857: 'o',
#  858: 'talking',
#  859: 'tc',
#  860: 'hungry',
#  861: '87066',
#  862: 'sending',
#  863: 'numbers',
#  864: 'finally',
#  865: 'through',
#  866: 'ans',
#  867: 'meant',
#  868: 'understand',
#  869: 'father',
#  870: 'difficult',
#  871: 'offers',
#  872: 'bslvyl',
#  873: 'wap',
#  874: 'frm',
#  875: 'uncle',
#  876: 'clean',
#  877: '12',
#  878: 'information',
#  879: "wasn't",
#  880: 'orchard',
#  881: 'case',
#  882: 'loads',
#  883: 'phones',
#  884: 'park',
#  885: 'ends',
#  886: 'happened',
#  887: 'truth',
#  888: 'police',
#  889: 'rply',
#  890: 'cut',
#  891: 'comp',
#  892: 'loved',
#  893: "'",
#  894: 'reveal',
#  895: 'bank',
#  896: 'extra',
#  897: 'via',
#  898: 'welcome',
#  899: 'checking',
#  900: 'across',
#  901: 'film',
#  902: '0800',
#  903: 'charged',
#  904: 'red',
#  905: 'spend',
#  906: 'leaves',
#  907: 'mrng',
#  908: 'motorola',
#  909: 'discount',
#  910: 'un',
#  911: 'redeemed',
#  912: '04',
#  913: 'comin',
#  914: 'tickets',
#  915: "you've",
#  916: 'seen',
#  917: 'bath',
#  918: 'abiola',
#  919: 'sex',
#  920: 'sound',
#  921: 'exam',
#  922: 'stupid',
#  923: 'gym',
#  924: 'ass',
#  925: "you'll",
#  926: 'hmv',
#  927: 'ac',
#  928: 'complimentary',
#  929: 'fr',
#  930: 'heard',
#  931: 'nyt',
#  932: 'kate',
#  933: 'mobiles',
#  934: 'call2optout',
#  935: 'std',
#  936: 'bcoz',
#  937: 'feels',
#  938: 'eg',
#  939: 'computer',
#  940: 'voice',
#  941: 'whole',
#  942: 'less',
#  943: 'b4',
#  944: 'normal',
#  945: 'usual',
#  946: 'laugh',
#  947: 'figure',
#  948: 'slowly',
#  949: 'picking',
#  950: 'wow',
#  951: 'wonderful',
#  952: 'knew',
#  953: 'dream',
#  954: 'couple',
#  955: 'hg',
#  956: 'study',
#  957: 'lost',
#  958: 'somebody',
#  959: 'ago',
#  960: 'mom',
#  961: 'sony',
#  962: 'th',
#  963: 'txts',
#  964: 'booked',
#  965: 'confirm',
#  966: 'india',
#  967: 'entered',
#  968: 'fantastic',
#  969: 'age',
#  970: 'wine',
#  971: 'p',
#  972: 'direct',
#  973: 'their',
#  974: 'surprise',
#  975: 'wana',
#  976: 'otherwise',
#  977: 'txting',
#  978: 'getzed',
#  979: 'dnt',
#  980: 'darren',
#  981: 'asking',
#  982: 'energy',
#  983: 'rental',
#  984: 'myself',
#  985: 'worried',
#  986: 'fact',
#  987: 'nobody',
#  988: 'supposed',
#  989: 'remove',
#  990: 'forwarded',
#  991: 'immediately',
#  992: 'hmmm',
#  993: 'sick',
#  994: 'custcare',
#  995: 'ntt',
#  996: 'crave',
#  997: 'å£350',
#  998: 'small',
#  999: 'ipod',
#  1000: 'bill',
#  ...}

# %%
TOT_SIZE = len(tok.word_index)+1
lstm_model = Sequential()
lstm_model.add(Embedding(TOT_SIZE, 32, input_length=max_len))
lstm_model.add(LSTM(100))
lstm_model.add(Dropout(0.4))
lstm_model.add(Dense(20, activation="relu"))
lstm_model.add(Dropout(0.3))
lstm_model.add(Dense(1, activation = "sigmoid"))

# %%
lstm_model.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 32)           262016
#
#  lstm (LSTM)                 (None, 100)               53200
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 20)                2020
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 317,257
# Trainable params: 317,257
# Non-trainable params: 0
# _________________________________________________________________

# %%
lstm_model.fit(sequences_matrix,Y_train,batch_size=128,epochs=10,
          validation_split=0.2,
          workers=10,
           callbacks=[EarlyStopping(monitor='val_loss',min_delta=0.0001)])
# Out:
# Epoch 1/10
# 30/30 [==============================] - 25s 769ms/step - loss: 0.4659 - accuracy: 0.8537 - val_loss: 0.3186 - val_accuracy: 0.8639
# Epoch 2/10
# 30/30 [==============================] - 13s 439ms/step - loss: 0.2146 - accuracy: 0.9271 - val_loss: 0.1167 - val_accuracy: 0.9715

# %%
test_sequences = tok.texts_to_sequences(X_test)
test_sequences_matrix = pad_sequences(test_sequences,maxlen=max_len)

# %%
acc = lstm_model.evaluate(test_sequences_matrix,Y_test)
# Out:
# 27/27 [==============================] - 1s 33ms/step - loss: 0.1239 - accuracy: 0.9725

# %%
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(acc[0],acc[1]))
# Out:
# Test set
#   Loss: 0.124
#   Accuracy: 0.972
